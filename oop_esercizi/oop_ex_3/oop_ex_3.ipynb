# %% [markdown]
# # OOP: Task 1

# %%
import oop_ex_3_utils as utils

# %% [markdown]
# ### Classe Atleta

# %%
nome_atleta = "Marco"
cognome_atleta = "Rossi"
medaglia = "A"
atleta = utils.Atleta(nome_atleta, cognome_atleta, medaglia)
print(atleta)

# %% [markdown]
# ### Classe Disciplina

# %%
nome_disciplina = "SaltoInLungo"
tipologia = "I"
disciplina = utils.Disciplina(nome_disciplina, tipologia)
print(disciplina)

# %%
disciplina.add_atleta(atleta)
print(disciplina)

# %% [markdown]
# ### Classe Medagliere

# %%
medagliere = utils.Medagliere(2, 3, 1)
print(medagliere)

# %% [markdown]
# ### Classe Nazione

# %%
nome_nazione = "Italia"
sigla_nazione = "ITA"
nazione = utils.Nazione(nome_nazione, sigla_nazione)
print(nazione)

# %% [markdown]
# ### Lettura File

# %%
nazioni = utils.read_file("input.txt")

# %% [markdown]
# ### Scrittura file

# %%
utils.write_file("output.txt", nazioni)

# %%
for nazione in nazioni:
    print(str(nazione))
