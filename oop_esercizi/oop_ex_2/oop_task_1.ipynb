# %% [markdown]
# # OOP: Task 1

# %%
import oop_task_1_utils as utils

# %% [markdown]
# ### Classe Data

# %%
data = utils.Data(giorno=1, mese=1, anno=2000)
print(data)
# Out:
# 01/01/2000

# %% [markdown]
# ### Classe attrezzatura

# %%
nome_attrezzatura = "Estintore"
codice_inventario = "EST-001"
data_prossima_revisione = utils.Data(giorno=1, mese=1, anno=2025)
attrezzatura = utils.Attrezzatura(nome_attrezzatura, codice_inventario, data_prossima_revisione)
print(attrezzatura)
# Out:
# [EST-001] Estintore (01/01/2025)

# %% [markdown]
# ### Classe Aula

# %%
nome_aula = "A101"
edificio = "Povo1"
capienza = 30
aula = utils.Aula(nome_aula, edificio, capienza)
print(aula)
# Out:
# A101 [Povo1] [30] [False]

# %%
aula.aggiungi_attrezzatura(attrezzatura)
print(aula)
# Out:
# A101 [Povo1] [30] [False]
# - [EST-001] Estintore (01/01/2025)

# %% [markdown]
# ### Lettura File

# %%
lista_aule = utils.read_file(file_path="input.txt")

# %%
for aula in lista_aule:
    print(aula)
# Out:
# A101 [Povo1] [150] [True]
# - [PRO1232958] Proiettore (15/01/2022)
# - [VS38726438] Telecamera (10/10/2021)
# - [DS32092966] LuceEmergenza (12/07/2021)
# - [LAV8547727] Lavagna (10/10/2021)
# - [DS34772647] Estintore (15/11/2022)
# - [DS32092985] Sirena (15/11/2022)
#
# A102 [Povo1] [30] [False]
# - [PRO1232959] Proiettore (15/01/2022)
# - [LAV8547727] Lavagna (10/10/2021)
# - [DS34772647] Estintore (15/11/2022)
# - [DS32092984] Sirena (10/07/2021)
#
# A103 [Povo1] [68] [True]
# - [DS0392085] LuceEmergenza (11/04/2022)
# - [LAV8547723] Lavagna (11/10/2021)
# - [DS398429] Estintore (11/04/2021)
# - [PRO1232955] Proiettore (18/01/2022)
# - [DS0930284] Sirena (11/09/2021)
#
# A104 [Povo1] [45] [False]
# - [DS0318014] Estintore (11/06/2021)
#
# A105 [Povo1] [50] [False]
# - [PRO309234] Proiettore (05/02/2023)
# - [LAV8938195] Lavagna (22/03/2023)
#
# A106 [Povo1] [120] [False]
# - [TG3902883] TavolettaGrafica (29/04/2023)
# - [LAV3892474] Lavagna (12/07/2021)
# ...

# %% [markdown]
# ### Scrittura File

# %%
utils.write_file(path="output.txt", lista_aule=lista_aule)
