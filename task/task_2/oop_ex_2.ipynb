# %% [markdown]
# # OOP: Esercizio 2

# %%
import oop_ex_2_utils as utils

# %% [markdown]
# ### Classe Data

# %%
data = utils.Data(giorno=1, mese=1, anno=2000)
print(data)
# Out:
# 01/01/2000

# %% [markdown]
# ### Classe Vaccinazione

# %%
data_vaccinazione = utils.Data(giorno=1, mese=2, anno=2021)
nome_vaccino = "Pfizer"
vaccinazione = utils.Vaccinazione(data_vaccinazione=data_vaccinazione, nome_vaccino=nome_vaccino)
print(vaccinazione)
# Out:
# 01/02/2021 [Pfizer]

# %% [markdown]
# ### Classe Persona

# %%
nome = "Rossi"
cognome = "Mario"
data_nascita = utils.Data(giorno=1, mese=1, anno=2000)
sesso = "M"
codice_fiscale = "RSSMRA00A01H501U"
persona = utils.Persona(nome=nome, cognome=cognome, data_nascita=data_nascita, sesso=sesso, codice_fiscale=codice_fiscale)
print(persona)
# Out:
# Mario Rossi [01/01/2000] [M] [RSSMRA00A01H501U]

# %%
persona.aggiungi_vaccinazione(vaccinazione=vaccinazione)
print(persona)
# Out:
# Mario Rossi [01/01/2000] [M] [RSSMRA00A01H501U]
# - 01/02/2021 [Pfizer]

# %% [markdown]
# ### Lettura File

# %%
lista_persone = utils.read_file(file_path="input.txt")

# %%
for p in lista_persone:
    print(p)
# Out:
# Siena Gilberta [05/04/1966] [F] [SNIGBR66D45L378A]
# - 20/05/2021 [AstraZeneca]
#
# Rossi Beppino [24/06/1967] [M] [RSSBPN67H24L378T]
# - 20/03/2021 [AstraZeneca]
# - 21/05/2021 [AstraZeneca]
#
# Folliero Davide [04/06/1969] [M] [FLLDVD69H04L378I]
# - 02/06/2021 [Johnson]
#
# Rossi Francesco [15/05/1976] [M] [RSSFNC76E15L378Z]
# - 05/05/2021 [Pfizer]
# - 26/05/2021 [Pfizer]
#
# Piazza Giovanni [26/09/1996] [M] [PZZGNN96P26A116X]
# - 05/06/2021 [Pfizer]
#
# Milano Elisabetta [10/08/1966] [F] [MLNLBT66M50L378M]
# - 08/04/2021 [AstraZeneca]
# - 07/06/2021 [AstraZeneca]
#
# Marchesi Mattia [05/04/1957] [M] [MRCMTT57D05L378N]
# - 05/06/2021 [Pfizer]
#
# Lettiere Roberta [27/06/1994] [F] [LTTRRT94H67A520G]
# - 01/06/2021 [Moderna]
#
# Verdi Giuseppe [26/02/1964] [M] [VRDGPP64B26L378I]
#
# Calabrese Natalino [12/12/1980] [M] [CLBNLN80T12M361G]
# - 08/06/2021 [AstraZeneca]
#
# Giordano Martina [01/01/1997] [F] [GRDMTN97A41L378Z]
# - 02/06/2021 [Johnson]
#
# Rocchetti Fausta [05/06/1969] [F] [FSTRCH69H45L378U]
# - 01/04/2021 [Moderna]
# - 22/04/2021 [Moderna]
#
# Ricci Giordana [04/08/1980] [F] [RCCGDN80M44L378F]
#
# Bernardi Lucia [05/10/1995] [F] [BRNLCU95R45L378M]
# - 01/05/2021 [Johnson]
#
# Ferri Augusto [27/10/1971] [M] [FRRGST71R27E506W]
# - 05/05/2021 [Moderna]
# - 26/05/2021 [Moderna]
#
# Lombardi Gustavo [31/12/1972] [M] [LMBGTV72T31E506V]
#
# Mancini Antonella [12/07/1939] [F] [MNCNNL39L52F205D]
# - 05/06/2021 [Pfizer]
#
# Testa Giuseppe [28/03/1991] [M] [TSTGPP91C28L736I]
# - 01/03/2021 [AstraZeneca]
# - 10/05/2021 [AstraZeneca]

# %% [markdown]
# ### Scrittura File

# %%
utils.write_file(path="output.txt", lista_persone=lista_persone)
