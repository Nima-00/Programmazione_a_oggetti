# %% [markdown]
# # Esercizio 1: Gestione della Campagna Vaccinale

# %%
import cognome_nome_ex_1_utils as utils

# %%
lista_persone = utils.read_file(file_path="input.txt")
for p in lista_persone:
    print(p)
    for vaccino in p.get_vaccinazioni():
        print(f"- {vaccino}")
    print()
