# %% [markdown]
# # Esercizio 1: Gestione della Campagna Vaccinale

# %%
class Data():
    
    def __init__(self, giorno: int, mese: int, anno: int):
        self.__giorno = giorno
        self.__mese = mese
        self.__anno = anno
    
    def get_giorno(self):
        return self.__giorno
    
    def get_mese(self):
        return self.__mese
    
    def get_anno(self):
        return self.__anno
    
    def __str__(self):
        return f"{self.__giorno}/{self.__mese}/{self.__anno}"

# %%
class Vaccinazione():

    def __init__(self, data: Data, nome_vaccino: str):
        self.__data = data
        self.__nome_vaccino = nome_vaccino
    
    def get_data(self):
        return self.__data
    
    def get_nome_vaccino(self):
        return self.__nome_vaccino
    
    def set_nome_vaccino(self, nome_vaccino: str):
        self.__nome_vaccino = nome_vaccino
    
    def __str__(self):
        return f"Vaccinazione: {self.__nome_vaccino} [{self.__data}]"

# %%
class Persona():

    def __init__(self, nome: str, cognome: str, data_nascita: Data, sesso: str):
        self.__nome = nome
        self.__cognome = cognome
        self.__data_nascita = data_nascita
        self.__sesso = sesso
        self.__vaccinazioni = []
    
    @classmethod
    def da_codice_fiscale(cls, nome: str, cognome: str, codice_fiscale: str):
        if len(codice_fiscale) != 16:
            raise ValueError("Il codice fiscale deve essere lungo 16 caratteri.")
        anno = 1900 + int(codice_fiscale[6:8])
        mese = "ABCDEHLMPRST".index(codice_fiscale[8]) + 1
        giorno = int(codice_fiscale[9:11])
        if giorno > 40:
            giorno -= 40
            sesso = "F"
        else:
            sesso = "M"
        return cls(nome, cognome, Data(giorno, mese, anno), sesso)
    
    def get_nome(self):
        return self.__nome
    
    def get_cognome(self):
        return self.__cognome
    
    def get_data_nascita(self):
        return self.__data_nascita
    
    def get_sesso(self):
        return self.__sesso
    
    def get_vaccinazioni(self):
        return self.__vaccinazioni
    
    def add_vaccinazione(self, vaccinazione: Vaccinazione):
        self.__vaccinazioni.append(vaccinazione)
    
    def get_numero_vaccinazioni(self):
        return len(self.__vaccinazioni)
    
    def ciclo_cocluso(self):
        ciclo_terminato = False
        A = 0
        M = 0
        P = 0
        for vaccinazione in self.__vaccinazioni:
            if vaccinazione.get_nome_vaccino() == "Johnson":
                ciclo_terminato = True
            elif vaccinazione.get_nome_vaccino() == "AstraZeneca":
                A += 1
            elif vaccinazione.get_nome_vaccino() == "Moderna":
                M += 1
            elif vaccinazione.get_nome_vaccino() == "Pfizer":
                P += 1
            if A == 2 or M == 2 or P == 2:
                ciclo_terminato = True
        return ciclo_terminato

# %%
txt_path = "input.txt"
lines = []
with open(txt_path) as f:
    for line in f:
        lines.append(line.strip())

print(lines)
# Out:
# ['Siena;Gilberta;5-4-1966;F;SNIGBR66D45L378A;AstraZeneca-20-5-2021', 'Rossi;Beppino;24-6-1967;M;RSSBPN67H24L378T;AstraZeneca-20-3-2021;AstraZeneca-21-05-2021', 'Folliero;Davide;4-6-1969;M;FLLDVD69H04L378I;Johnson-2-6-2021', 'Rossi;Francesco;15-5-1976;M;RSSFNC76E15L378Z;Pfizer-5-5-2021;Pfizer-26-5-2021', 'Piazza;Giovanni;26-9-1996;M;PZZGNN96P26A116X;Pfizer-5-6-2021', 'Milano;Elisabetta;10-8-1966;F;MLNLBT66M50L378M;AstraZeneca-8-4-2021;AstraZeneca-7-6-2021', 'Marchesi;Mattia;5-4-1957;M;MRCMTT57D05L378N;Pfizer-5-6-2021', 'Lettiere;Roberta;27-6-1994;F;LTTRRT94H67A520G;Moderna-1-6-2021', 'Verdi;Giuseppe;26-2-1964;M;VRDGPP64B26L378I', 'Calabrese;Natalino;12-12-1980;M;CLBNLN80T12M361G;AstraZeneca-8-6-2021', 'Giordano;Martina;1-1-1997;F;GRDMTN97A41L378Z;Johnson-2-6-2021', 'Rocchetti;Fausta;5-6-1969;F;FSTRCH69H45L378U;Moderna-1-4-2021;Moderna-22-4-2021', 'Ricci;Giordana;4-8-1980;F;RCCGDN80M44L378F', 'Bernardi;Lucia;5-10-1995;F;BRNLCU95R45L378M;Johnson-1-5-2021', 'Ferri;Augusto;27-10-1971;M;FRRGST71R27E506W;Moderna-5-5-2021;Moderna-26-5-2021', 'Lombardi;Gustavo;31-12-1972;M;LMBGTV72T31E506V', 'Mancini;Antonella;12-7-1939;F;MNCNNL39L52F205D;Pfizer-5-6-2021', 'Testa;Giuseppe;28-3-1991;M;TSTGPP91C28L736I;AstraZeneca-1-3-2021;AstraZeneca-10-5-2021']

# %%
def read_file(file_path: str) -> list[Persona]:
    lista_persone = []
    with open(file_path) as f:
        for line in f:
            line = line.strip()
            terms = line.split(sep=";")
            print(terms)

# %%
read_file(txt_path)
# Out:
# ['Siena', 'Gilberta', '5-4-1966', 'F', 'SNIGBR66D45L378A', 'AstraZeneca-20-5-2021']
# ['Rossi', 'Beppino', '24-6-1967', 'M', 'RSSBPN67H24L378T', 'AstraZeneca-20-3-2021', 'AstraZeneca-21-05-2021']
# ['Folliero', 'Davide', '4-6-1969', 'M', 'FLLDVD69H04L378I', 'Johnson-2-6-2021']
# ['Rossi', 'Francesco', '15-5-1976', 'M', 'RSSFNC76E15L378Z', 'Pfizer-5-5-2021', 'Pfizer-26-5-2021']
# ['Piazza', 'Giovanni', '26-9-1996', 'M', 'PZZGNN96P26A116X', 'Pfizer-5-6-2021']
# ['Milano', 'Elisabetta', '10-8-1966', 'F', 'MLNLBT66M50L378M', 'AstraZeneca-8-4-2021', 'AstraZeneca-7-6-2021']
# ['Marchesi', 'Mattia', '5-4-1957', 'M', 'MRCMTT57D05L378N', 'Pfizer-5-6-2021']
# ['Lettiere', 'Roberta', '27-6-1994', 'F', 'LTTRRT94H67A520G', 'Moderna-1-6-2021']
# ['Verdi', 'Giuseppe', '26-2-1964', 'M', 'VRDGPP64B26L378I']
# ['Calabrese', 'Natalino', '12-12-1980', 'M', 'CLBNLN80T12M361G', 'AstraZeneca-8-6-2021']
# ['Giordano', 'Martina', '1-1-1997', 'F', 'GRDMTN97A41L378Z', 'Johnson-2-6-2021']
# ['Rocchetti', 'Fausta', '5-6-1969', 'F', 'FSTRCH69H45L378U', 'Moderna-1-4-2021', 'Moderna-22-4-2021']
# ['Ricci', 'Giordana', '4-8-1980', 'F', 'RCCGDN80M44L378F']
# ['Bernardi', 'Lucia', '5-10-1995', 'F', 'BRNLCU95R45L378M', 'Johnson-1-5-2021']
# ['Ferri', 'Augusto', '27-10-1971', 'M', 'FRRGST71R27E506W', 'Moderna-5-5-2021', 'Moderna-26-5-2021']
# ['Lombardi', 'Gustavo', '31-12-1972', 'M', 'LMBGTV72T31E506V']
# ['Mancini', 'Antonella', '12-7-1939', 'F', 'MNCNNL39L52F205D', 'Pfizer-5-6-2021']
# ['Testa', 'Giuseppe', '28-3-1991', 'M', 'TSTGPP91C28L736I', 'AstraZeneca-1-3-2021', 'AstraZeneca-10-5-2021']
